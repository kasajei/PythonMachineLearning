# %% [markdown]
# # これはSandboxです
#
# ipython notebookを使って見るためのサンプル
#
# ## ショートカット
#
# - コマンドモードでhで出現する

# %% [markdown]
# ## 数式
#
# 文中に入れるには、$y=f(x)$こうする
#
#
# 中央に独立して入れるなら、こうする $$y=f(x)$$
#
#
# 長い数式なら、が書きやすい
# \begin{equation*} y=f(x) \end{equation*}

# %% [markdown]
# # Jupyterのサンプルを実行してみる

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt
import seaborn as sns

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')
